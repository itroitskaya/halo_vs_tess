# %%
import matplotlib as mpl
from lightkurve import search_targetpixelfile
import lightkurve as lk

# %%
# download a star
name = "EPIC 200173854"
search_result = lk.search_targetpixelfile(name, author="K2", cadence="long")

# %%
tpf = search_result[0].download()
tpf.plot(scale = 'log')
# Out:
# <AxesSubplot:title={'center':'Target ID: 200173854, Cadence: 140878'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf.interact()
# Out:
# <script id="1376">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:57770/autoload.js?bokeh-autoload-element=1376&bokeh-absolute-url=http://localhost:57770&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>

# %%
tpf.interact_sky()
# Out:
# <script id="1564">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:57774/autoload.js?bokeh-autoload-element=1564&bokeh-absolute-url=http://localhost:57774&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# WARNING: UnitsWarning: Unit 'e' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING:astroquery:UnitsWarning: Unit 'e' not supported by the VOUnit standard.
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=1564&bokeh-absolute-url=http://localhost:57774&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:57774', method='GET', uri='/autoload.js?bokeh-autoload-element=1564&bokeh-absolute-url=http://localhost:57774&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = await self.get_session()
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/bokeh/server/views/session_handler.py", line 120, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/bokeh/server/contexts.py", line 218, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/bokeh/application/application.py", line 171, in initialize_document
#     h.modify_document(doc)
#   File "/Users/kote_electric/opt/anaconda3/lib/python3.8/site-packages/bokeh/application/handlers/function.py", line 132, in modify_document
#     self._func(doc)
#   File "/Users/research/.local/lib/python3.8/site-packages/lightkurve/interact.py", line 1131, in create_interact_ui
#     fig_tpf, r, message_selected_target = add_gaia_figure_elements(
#   File "/Users/research/.local/lib/python3.8/site-packages/lightkurve/interact.py", line 495, in add_gaia_figure_elements
#     target_ra, target_dec, pm_corrected = _get_corrected_coordinate(tpf)
#   File "/Users/research/.local/lib/python3.8/site-packages/lightkurve/interact.py", line 133, in _get_corrected_coordinate
#     pm_ra * pm_unit, pm_dec * pm_unit,
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'CompositeUnit'
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=1564&bokeh-absolute-url=http://localhost:57774&resources=none (::1) 275.85ms
