# %%
import pandas as pd
import lightkurve as lk
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from astropy.io import fits
from astropy import units as u
from astropy.utils.data import get_pkg_data_filename
from astropy.timeseries import LombScargle
from astropy.table import Table
from scipy.signal import savgol_filter as savgol
from pathlib import Path
from scipy import ndimage

import copy
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
target = "98 Tau"
tpf = lk.search_targetpixelfile(target, mission="TESS", cadence=120)

# %%
tpf = tpf_search[0].download()

# %%
tpf.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: 85043188, Cadence: 897633'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf.interact()
# Out:
# <script id="2369">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:58045/autoload.js?bokeh-autoload-element=2369&bokeh-absolute-url=http://localhost:58045&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>

# %%
lc = tpf.to_lightcurve()

# %%
lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
target = "98 Tau" 
tpf = lk.search_tesscut(target).download(cutout_size=(50, 50))

# %%
tpf.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: 98 Tau, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf.interact()
# Out:
# <script id="1936">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:57908/autoload.js?bokeh-autoload-element=1936&bokeh-absolute-url=http://localhost:57908&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
